# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import matplotlib
import glob, os
matplotlib.use('Qt5Agg')
#%matplotlib inline
import preprocessing as prep
import scot
import mne_connectivity as mnecon
import scipy
import pickle

# %%
from epoch_connectivity import ConnEEG as cnegg

# %%
#SCOT PAPER https://www.frontiersin.org/articles/10.3389/fninf.2014.00022/full

# %%
epoched = prep.open_preprocessed_epoched(1, weaning=False)

a = (epoched[1]).copy()
#a.drop_channels(['ECG1', 'ECG2'])
sampling_frequency = a.info['sfreq']
b = (a.get_data(picks=['eeg']))
# Out:
# Reading C:\code_thesis\brain_connectivity_epilepsy\preprocessed\PAT1_AWAKE-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...   10000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Reading C:\code_thesis\brain_connectivity_epilepsy\preprocessed\PAT1_SLEEP-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...   10000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# C:\code_thesis\brain_connectivity_epilepsy\preprocessing.py:156: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epoched.append(mne.read_epochs(a_file, proj=False, preload=True, verbose=None))
# C:\code_thesis\brain_connectivity_epilepsy\preprocessing.py:156: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epoched.append(mne.read_epochs(a_file, proj=False, preload=True, verbose=None))
# C:\code_thesis\brain_connectivity_epilepsy\preprocessing.py:157: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epoched.append(mne.read_epochs(b_file, proj=False, preload=True, verbose=None))
# C:\code_thesis\brain_connectivity_epilepsy\preprocessing.py:157: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
#   epoched.append(mne.read_epochs(b_file, proj=False, preload=True, verbose=None))

# %%
ABLUBLE = cnegg.EEG_SpectralConnection(a)
ABLUBLE.plot_connectivity_hmp(measure = 'wpli', frequency_band = [0.5, 3])
# Out:
# Connectivity computation...
# only using indices for lower-triangular matrix
#     computing connectivity for 210 connections
#     using t=0.000s..10.000s for estimation (2561 points)
#     frequencies: 0.6Hz..3.0Hz (25 points)
#     connectivity scores will be averaged for each band
#     Using multitaper spectrum estimation with 7 DPSS windows
#     the following metrics will be computed: WPLI
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     assembling connectivity matrix
# [Connectivity computation done]

# %%
myConn = cnegg.EEG_DirectedConnection(a)

# %%
myConn.fit_MVAR_on_epochs()
# Out:
# c:\program files\python37\lib\site-packages\scot\external\infomax_.py:183: RuntimeWarning: overflow encountered in exp
#   y = 1.0 / (1.0 + np.exp(-u))

# %%
myConn.plot_connectivity_hmp(measure='dDTF', frequency_band=[0, 30])

# %%
QWERTY = myConn.integrated_measure_epochs('PDC', nfft=512, frequency_band=[5, 10])
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

ax = sns.heatmap(QWERTY, linewidth=0.1, cmap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-06068bca28df> in <module>
#       4 import matplotlib.pylab as plt
#       5
# ----> 6 ax = sns.heatmap(QWERTY, linewidth=0.1, cmpa='viridis')
#       7 plt.show()
#
# c:\program files\python37\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\program files\python37\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     556     if square:
#     557         ax.set_aspect("equal")
# --> 558     plotter.plot(ax, cbar_ax, kwargs)
#     559     return ax
#     560
#
# c:\program files\python37\lib\site-packages\seaborn\matrix.py in plot(self, ax, cax, kws)
#     306
#     307         # Draw the heatmap
# --> 308         mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     309
#     310         # Set the axis limits
#
# c:\program files\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# c:\program files\python37\lib\site-packages\matplotlib\axes\_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    5994         collection = mcoll.QuadMesh(Nx - 1, Ny - 1, coords,
#    5995                                     antialiased=antialiased, shading=shading,
# -> 5996                                     **kwargs)
#    5997         collection.set_alpha(alpha)
#    5998         collection.set_array(C)
#
# c:\program files\python37\lib\site-packages\matplotlib\collections.py in __init__(self, meshWidth, meshHeight, coordinates, antialiased, shading, **kwargs)
#    1811     def __init__(self, meshWidth, meshHeight, coordinates,
#    1812                  antialiased=True, shading='flat', **kwargs):
# -> 1813         Collection.__init__(self, **kwargs)
#    1814         self._meshWidth = meshWidth
#    1815         self._meshHeight = meshHeight
#
# c:\program files\python37\lib\site-packages\matplotlib\collections.py in __init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, transOffset, norm, cmap, pickradius, hatch, urls, offset_position, zorder, **kwargs)
#     164
#     165         self._path_effects = None
# --> 166         self.update(kwargs)
#     167         self._paths = None
#     168
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# c:\program files\python37\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     910                 func = getattr(self, 'set_' + k, None)
#     911                 if not callable(func):
# --> 912                     raise AttributeError('Unknown property %s' % k)
#     913                 return func(v)
#     914
#
# AttributeError: Unknown property cmpa

# %%
QWERTY = myConn.integrated_measure_epochs('PDC', nfft=512, frequency_band=[5, 10])

# %%
pickle.dump(myConn, open( "save.p", "wb" ))

# %%
myConnLoaded = pickle.load( open( "save.p", "rb" ) )

# %%
QWERTY = myConnLoaded.integrated_measure_epochs('PDC', nfft=512, frequency_band=[5, 10])

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

ax = sns.heatmap(QWERTY, linewidth=0.1)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

ax = sns.heatmap(QWERTY, linewidth=0.1)
plt.show()

# %%
"""The first dimension is the sink, the second dimension is the source"""
# Out:
# 'The first dimension is the sink, the second dimension is the source'

# %%
varx = scot.var.VAR(model_order=20)
result = scot.varica.mvarica(x=b[0:10], var=varx, reducedim='no_pca', optimize_var=True, varfit='trial')
# Out:
# c:\program files\python37\lib\site-packages\scot\external\infomax_.py:183: RuntimeWarning: overflow encountered in exp
#   y = 1.0 / (1.0 + np.exp(-u))

# %%
np.shape(result.a.coef)
# Out:
# (19, 380)

# %%
conn = scot.Connectivity(b = result.a.coef, c = result.a.rescov, nfft=512)

# %%
cm_1 = conn.PDC()
np.shape(cm_1)
# Out:
# (19, 19, 512)

# %%
x = np.linspace(0, sampling_frequency/2, 512)
asdf = scipy.integrate.simps(y=cm_1[:,:,0:10], x=x[0:10])

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

ax = sns.heatmap(asdf, linewidth=0.1)
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt

ax = sns.heatmap(asdf, linewidth=0.1)
plt.show()

# %%
x = np.linspace(0, sampling_frequency/2, 512)
asdf = scipy.integrate.simps(y=cm_1[:,:,0:10], x=x[0:10])
ax = sns.heatmap(asdf, linewidth=0.1)
plt.show()

# %%
x = np.linspace(0, sampling_frequency/2, 512)
asdf = scipy.integrate.simps(y=cm_1[:,:,0:10], x=x[0:10])
ax = sns.heatmap(asdf, linewidth=0.1)
plt.show()
