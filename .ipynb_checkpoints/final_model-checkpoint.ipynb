# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import glob, os
#matplotlib.use('Qt5Agg')
# %matplotlib inline
import preprocessing as prep
import scot
import mne_connectivity as mnecon
import connectivipy as cp

# %%
epoched = prep.open_preprocessed_epoched(8, weaning=False)

a = (epoched[0]).copy()
a.drop_channels(['ECG1', 'ECG2'])
sampling_frequency = a.info['sfreq']
b = (a.get_data())[0]
# Out:
# Reading C:\Users\igorc\OneDrive\Desktop\POLI\UCLouvain\3º Semestre\Thesis\Data\preprocessed\PAT8_AWAKE-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...   10000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# Reading C:\Users\igorc\OneDrive\Desktop\POLI\UCLouvain\3º Semestre\Thesis\Data\preprocessed\PAT8_SLEEP-epo.fif ...
# Isotrak not found
#     Found the data of interest:
#         t =       0.00 ...   10000.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# Not setting metadata
# 10 matching events found
# No baseline correction applied
# C:\Users\igorc\OneDrive\Desktop\POLI\UCLouvain\3º Semestre\Thesis\Data\preprocessing.py:156: RuntimeWarning: The events passed to the Epochs constructor are not chronologically ordered.
# ...

# %%
epoched
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-54850f57db01> in <module>
# ----> 1 epoched
#
# NameError: name 'epoched' is not defined

# %%
#myMVAR = cp.Mvar()
myMVAR = scot.var.VAR(model_order=11)

# %%
myMVAR.fit(data = b)

# %%
c = np.array([b])
X, Y = scot.varbase._construct_var_eqns(data=c, p=1)
selected_orders = mnecon.vector_ar.select_order(X, maxlags=30)
selected_order = selected_orders['bic']
myMVAR = scot.var.VAR(model_order=selected_order)
myMVAR.fit(data=b)

# %%
nfft = int(sampling_frequency) # number of frequency bins
Connec = scot.Connectivity(b = myMVAR.coef, c = myMVAR.rescov, nfft = nfft)

# %%
np.shape(Connec.dDTF())
# Out:
# (19, 19, 256)

# %%
res = (fs/2)/(nfft - 1) # The resolution of the frequency bins
int(128/res) # Postion of the frequency on the frequency bins
# Out:
# 255

# %%
low = int(0/res)
high = int(10/res)

dDTF = Connec.dDTF()
np.shape(dDTF[:][:][low:high+1])
# Out:
# (19, 19, 256)

# %%
dDTF[0][0][low:high+1].sum()
# Out:
# 185.76960567740167

# %%
np.sum(dDTF[:,:,low:high+1], axis=2)
# Out:
# array([[185.76960568, 184.83150691, 184.81208468, 184.96217199,
#         184.95494413, 184.88158961, 185.05926446, 184.78670583,
#         184.77927452, 184.8570885 , 184.77168957, 184.89541873,
#         184.862942  , 184.97794877, 185.02108892, 184.85218826,
#         184.89914284, 184.68049222, 184.6801784 ],
#        [158.47190774, 158.10934435, 158.00467783, 158.1634267 ,
#         158.17681122, 157.85393406, 158.09552032, 158.15638747,
#         157.97549964, 157.98191037, 158.00387291, 157.98994959,
#         158.0196602 , 158.14565379, 157.96271118, 158.03429256,
#         158.22263855, 158.09424514, 158.1836175 ],
#        [135.50934361, 135.03998097, 135.02658692, 135.08005283,
#         135.26063451, 135.46533564, 134.7635031 , 135.15042775,
#         135.10632021, 135.11977783, 135.02049232, 135.11655464,
#         135.15040296, 135.37650571, 135.40065493, 134.95479323,
#         135.34836398, 135.05806769, 135.02149096],
# ...

# %%
dDTF()
# Out:
# (19, 19, 256)

# %%
freq = np.linspace(0, fs/2, nfft)
freq
# Out:
# array([  0.        ,   0.50196078,   1.00392157,   1.50588235,
#          2.00784314,   2.50980392,   3.01176471,   3.51372549,
#          4.01568627,   4.51764706,   5.01960784,   5.52156863,
#          6.02352941,   6.5254902 ,   7.02745098,   7.52941176,
#          8.03137255,   8.53333333,   9.03529412,   9.5372549 ,
#         10.03921569,  10.54117647,  11.04313725,  11.54509804,
#         12.04705882,  12.54901961,  13.05098039,  13.55294118,
#         14.05490196,  14.55686275,  15.05882353,  15.56078431,
#         16.0627451 ,  16.56470588,  17.06666667,  17.56862745,
#         18.07058824,  18.57254902,  19.0745098 ,  19.57647059,
#         20.07843137,  20.58039216,  21.08235294,  21.58431373,
#         22.08627451,  22.58823529,  23.09019608,  23.59215686,
#         24.09411765,  24.59607843,  25.09803922,  25.6       ,
#         26.10196078,  26.60392157,  27.10588235,  27.60784314,
#         28.10980392,  28.61176471,  29.11372549,  29.61568627,
# ...

# %%
Connec.dDTF()
# Out:
# array([[[2.32869462e+01, 2.22341063e+01, 1.53999843e+01, ...,
#          2.29056999e-07, 2.28723792e-07, 2.28557283e-07],
#         [2.32041985e+01, 2.21552379e+01, 1.53277629e+01, ...,
#          3.32663930e-09, 2.73635366e-09, 2.38391395e-09],
#         [2.32045152e+01, 2.21540799e+01, 1.53217112e+01, ...,
#          1.56368977e-08, 1.54392191e-08, 1.53394945e-08],
#         ...,
#         [2.32341469e+01, 2.21834801e+01, 1.53457877e+01, ...,
#          2.52660848e-08, 2.51483181e-08, 2.50889128e-08],
#         [2.31879115e+01, 2.21334296e+01, 1.52992269e+01, ...,
#          3.28461407e-09, 3.23683588e-09, 3.21276376e-09],
#         [2.32071799e+01, 2.21624274e+01, 1.53380386e+01, ...,
#          2.31583869e-08, 2.32065111e-08, 2.32305244e-08]],
#
#        [[2.29652353e+01, 2.37713109e+01, 2.01110780e+01, ...,
#          6.23230124e-10, 4.48111048e-10, 3.58978834e-10],
#         [2.29534881e+01, 2.37618834e+01, 2.01064299e+01, ...,
# ...

# %%
print((myMVAR.predict(b))[0][1][-10:])
# Out:
# [-4.31625664e-07 -7.66124692e-07 -1.06783605e-06 -1.33858509e-06
#  -1.60658699e-06 -1.93193947e-06 -2.33238256e-06 -2.71678773e-06
#  -2.88447174e-06 -2.60990054e-06]

# %%
print(b[1][-10:])
# Out:
# [-4.30507010e-07 -7.67628729e-07 -1.06841090e-06 -1.33738600e-06
#  -1.60723945e-06 -1.93257412e-06 -2.33175384e-06 -2.71693417e-06
#  -2.88463590e-06 -2.60999942e-06]

# %%
b = np.array([b])

# %%
conn = mnecon.vector_auto_regression(data=b, times=a.times, names=a.ch_names, lags=1)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 50.13it/s]

# %%
np.shape(conn._data)
# Out:
# (1, 361)

# %%
conn.predict(data=b)
# Out:
# array([[[ 0.00000000e+00,  3.11925976e-06,  3.83603735e-06, ...,
#           3.04706458e-06,  2.35033181e-06,  1.67710430e-06],
#         [ 0.00000000e+00,  1.09409767e-06,  2.18779212e-06, ...,
#          -2.45179793e-06, -2.87124861e-06, -3.05134096e-06],
#         [ 0.00000000e+00, -2.18490882e-06, -2.25027708e-06, ...,
#          -6.27950500e-07, -3.74637217e-08,  1.16459730e-06],
#         ...,
#         [ 0.00000000e+00,  4.84593718e-07,  1.47167561e-06, ...,
#          -4.29429439e-06, -4.63559033e-06, -4.75374615e-06],
#         [ 0.00000000e+00, -4.12534155e-07, -3.42923349e-07, ...,
#          -2.63124755e-06, -1.75266135e-06, -8.51523439e-07],
#         [ 0.00000000e+00, -5.76207347e-07, -5.19584339e-07, ...,
#           1.18507597e-06,  1.40466533e-06,  1.68390296e-06]]])

# %%
b
# Out:
# array([[[ 3.25057044e-06,  4.11964493e-06,  5.04189120e-06, ...,
#           2.53816552e-06,  1.92765583e-06,  1.59337503e-06],
#         [ 1.27171279e-06,  2.52762538e-06,  3.42934823e-06, ...,
#          -2.76099900e-06, -2.92870072e-06, -2.65406425e-06],
#         [-2.30683395e-06, -2.15800333e-06, -2.26885845e-06, ...,
#          -2.31623559e-07,  9.98271162e-07,  2.13613816e-06],
#         ...,
#         [ 6.12569465e-07,  1.72543071e-06,  2.44184685e-06, ...,
#          -4.67469272e-06, -4.70524674e-06, -4.18653917e-06],
#         [-5.56645318e-07, -4.57274439e-07, -5.57814950e-09, ...,
#          -1.75750552e-06, -7.50820902e-07,  9.87093074e-08],
#         [-8.41510030e-07, -8.20909861e-07, -5.64110678e-07, ...,
#           1.55691021e-06,  1.87856006e-06,  1.96464953e-06]]])

# %%
#X, Y = mnecon.vector_ar.var._construct_var_eqns(data=b, lags=1)
#selected_orders = mnecon.vector_ar.select_order(X, maxlags=30)
#selected_order = selected_orders['bic']
conn = mnecon.vector_auto_regression(data=b, times=a.times, names=a.ch_names, lags=5)#, lags=selected_order)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 20.89it/s]

# %%
(conn._data)[0][340] # [17][17]
# Out:
# array([ 1366.92577682,   939.39788698,   224.63968929,  -620.72671361,
#        -1341.61408797])

# %%
conn.c

# %%
test = a.reshape((19,19,5))

# %%
dim = test.shape

# %%
to_conc = []
for i in range(dim[2]):
    to_conc.append(test[:,:,i])
concatenated = np.concatenate(to_conc, axis=1)

# %%
myCon = scot.connectivity.Connectivity(b=concatenated, nfft=int(sampling_frequency/2))

# %%
myCon.dDTF()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\scot\utils.py in __call__(self, *args, **kw)
#     145         try:
# --> 146             res = cache[key]
#     147         except KeyError:
#
# KeyError: (<function Connectivity.dDTF at 0x000001A06F18F048>, (), frozenset())
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\scot\utils.py in __call__(self, *args, **kw)
#     145         try:
# --> 146             res = cache[key]
#     147         except KeyError:
#
# KeyError: (<function Connectivity.pCOH at 0x000001A078CDDB70>, (), frozenset())
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
c = b - b.mean(axis=1, keepdims=True)
c
# Out:
# array([[ 3.36938897e-06,  4.23846346e-06,  5.16070973e-06, ...,
#          2.65698405e-06,  2.04647436e-06,  1.71219356e-06],
#        [ 1.31577761e-06,  2.57169021e-06,  3.47341305e-06, ...,
#         -2.71693417e-06, -2.88463590e-06, -2.60999942e-06],
#        [-2.19751381e-06, -2.04868319e-06, -2.15953832e-06, ...,
#         -1.22303424e-07,  1.10759130e-06,  2.24545830e-06],
#        ...,
#        [ 6.08222877e-07,  1.72108412e-06,  2.43750026e-06, ...,
#         -4.67903931e-06, -4.70959333e-06, -4.19088576e-06],
#        [-6.05408240e-07, -5.06037361e-07, -5.43410714e-08, ...,
#         -1.80626844e-06, -7.99583824e-07,  4.99463855e-08],
#        [-8.55092144e-07, -8.34491975e-07, -5.77692792e-07, ...,
#          1.54332809e-06,  1.86497794e-06,  1.95106741e-06]])

# %%
d = b.var(axis=1)
d
# Out:
# array([2.82445544e-11, 2.08773412e-11, 3.33037997e-11, 1.11930733e-11,
#        2.02647423e-11, 2.11512961e-11, 1.19444850e-11, 2.60393644e-11,
#        3.57534149e-11, 2.20753030e-11, 4.94465835e-11, 1.76106147e-11,
#        4.53797452e-11, 1.93740445e-11, 1.39265871e-11, 2.32979168e-11,
#        1.59931642e-11, 1.20910770e-11, 1.30168762e-11])

# %%
d = b.var(axis=1)
test = c / d[:,None]

# %%
coef_matrix, reflection_matrix = cp.Mvar.fit(data=test, order=None, method='yw')
# Out:
# c:\program files\python37\lib\site-packages\connectivipy\mvar\fitting.py:267: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   req = np.vstack(rr_b[:, :, x].T for x in range(1, pmax+1))
# c:\program files\python37\lib\site-packages\connectivipy\mvarmodel.py:114: RuntimeWarning: invalid value encountered in log
#   crit[p] = np.log(np.linalg.det(v_r))+2.*np.log(np.log(N))*(p+1)*chn**2/N

# %%
# Out:
# (1, 19, 19)
